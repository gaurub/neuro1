# %%
import tensorflow as tf

# %%
import numpy as np

# %%
x = np.linspace(-5,5,1000)
y = 3*x + 2 + np.random.randn(x.shape[0])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'bo')
plt.show()

# %%
x = x.reshape((1000,1))

# %%
x.shape
# Out:
# (1000, 1)

# %%
sess = tf.Session()
tf.keras.backend.set_session(sess)

# %%
inp = tf.keras.layers.Input(shape=(1,))
d = tf.keras.layers.Dense(1)(inp)
model = tf.keras.models.Model(inp, d)
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(x,y,epochs=200)
# Out:
# Epoch 1/200
# 1000/1000 [==============================] - 0s - loss: 38.3550
# Epoch 2/200
# 1000/1000 [==============================] - 0s - loss: 37.2075
# Epoch 3/200
# 1000/1000 [==============================] - 0s - loss: 36.0775
# Epoch 4/200
# 1000/1000 [==============================] - 0s - loss: 34.9738
# Epoch 5/200
# 1000/1000 [==============================] - 0s - loss: 33.9027
# Epoch 6/200
# 1000/1000 [==============================] - 0s - loss: 32.8445
# Epoch 7/200
# 1000/1000 [==============================] - 0s - loss: 31.8342
# Epoch 8/200
# 1000/1000 [==============================] - 0s - loss: 30.8238
# Epoch 9/200
# 1000/1000 [==============================] - 0s - loss: 29.8398
# Epoch 10/200
# 1000/1000 [==============================] - 0s - loss: 28.8986
# Epoch 11/200
# 1000/1000 [==============================] - 0s - loss: 27.9661
# Epoch 12/200
# 1000/1000 [==============================] - 0s - loss: 27.0677
# Epoch 13/200
# ...

# %%
outputTensor = model.output

# %%
listofVariableTensors = model.trainable_weights

# %%
for i in listOfVariableTensors:
    print(i)

# %%
model.get_weights()
# Out:
# [array([[ 2.98848915]], dtype=float32), array([ 2.0293963], dtype=float32)]

# %%
x

# %%
x.dtype

# %%
grads = tf.keras.backend.gradients(model.output, model.input)

# %%
evaluated_gradients = sess.run(grads, feed_dict={model.input:x})

# %%
evaluated_gradients
# Out:
# [array([[ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
#         [ 2.98848915],
# ...
